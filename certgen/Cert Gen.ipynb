# %% [markdown]
# # Cert Generator
#
# Goal of this project is to:
# 1. Do simple Data Analysis
#   - Deal with missing values
#   - Format the date or text
# 2. Enhance Python concepts
# 3. Explore more 3rd party libraries - reportlab

# %% [markdown]
# ## 1. Download & Import packages for this project

# %%
# reportlab; a library to link pdf to python program

# 'pip' is a python package downloader (package manager)
# pip package manager is like ur Appstore to download apps

# !pip install reportlab
# Out:
# Collecting reportlab
#   Downloading reportlab-4.3.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.11/dist-packages (from reportlab) (11.1.0)
# Requirement already satisfied: chardet in /usr/local/lib/python3.11/dist-packages (from reportlab) (5.2.0)
# Downloading reportlab-4.3.0-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 16.3 MB/s eta 0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.3.0

# %%
# mount google drive
# we are linking to gdrive because our excel file is here

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

from reportlab.lib.pagesizes import landscape, A4
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont

# %% [markdown]
# ## 2. Reading and Exploring the Excel File

# %%
df = pd.read_excel('/content/drive/MyDrive/certgen/dataset.xlsx') # converts excel to pandas dataframe

# %%
df

# realize that 2 of the rows are empty/half empty

# NaN - Not a Number
# NaT - Not a Time
# "-"
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 4                    -                    NaN      Advanced        NaT
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 8      Jonathan Bucker                    NaN           NaN        NaT
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20

# %%
df.info()

# from this info, we know that there are 4 columns and 13 rows (some of them are empty)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         13 non-null     object
#  1   Course       11 non-null     object
#  2   CourseLevel  12 non-null     object
#  3   Date         11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 548.0+ bytes

# %% [markdown]
# ## 3. Data Cleaning (Data Analyis)
#
# Data cleaning - Formatting the data before doing the certificate generator logic
#
# - Deal with missing values
# - Format the date or text

# %%
# the problems with the original dataset (raw excel file)

# 1. Empty values (half empty row 4 & 8)
# 2. Inconsistency formatting in "Course" & "CourseLevel" columns - some of them are capitalized some are uppercase
# 3. Date format (yyyy/mm/dd) --> (dd/mm/yyyy)

# we are going to solve all these problems using Data Analysis with Pandas

# %%
df
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 4                    -                    NaN      Advanced        NaT
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 8      Jonathan Bucker                    NaN           NaN        NaT
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20

# %%
# Problem 1 - missing data

df = df.dropna() # drop all the rows that have AT LEAST 1 empty cell/column
# in this case, it will drop row 4 & 8

# %%
df # from 13 --> 11 data left
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20

# %%
# Problem 2: Inconsistency formatting in "Course" & "CourseLevel" columns

# .str --> u can access to multiple string methods onto data in pandas df

df['Course'] = df['Course'].str.title()
df['CourseLevel'] = df['CourseLevel'].str.title()

# broadcasting function --> broadcast the logic of capitalization to all the rows in "Course" & "CourseLevel" columns
# Out:
# <ipython-input-11-6eab8fba4742>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Course'] = df['Course'].str.title()
# <ipython-input-11-6eab8fba4742>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CourseLevel'] = df['CourseLevel'].str.title()

# %%
df
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 Python       Master  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  Ai & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 Python       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  Ai & Machine Learning      Beginner 2023-09-20

# %%
# Problem 3: Date Format (yyyy-mm-dd) --> (dd/mm/yyyy)

df['Date']
# Out:
# 0    2023-09-10
# 1    2023-09-11
# 2    2023-09-12
# 3    2023-09-13
# 5    2023-09-14
# 6    2023-09-15
# 7    2023-09-16
# 9    2023-09-17
# 10   2023-09-18
# 11   2023-09-19
# 12   2023-09-20
# Name: Date, dtype: datetime64[ns]

# %%
df['Date'].iloc[0]
# iloc --> index location

# Timestamp is a data type to represent time in (excel, df)
# for example, we need to change Timestamp('2023-09-10 00:00:00') --> '10/09/2023'
# Out:
# Timestamp('2023-09-10 00:00:00')

# %%
# create a new column called 'FormattedDate' > create a new date format based off of the 'Date' column
# then remove 'Date' column
# .dt --> allows u to access datetime objects' methods

df['FormattedDate'] = df['Date'].dt.strftime('%d/%m/%Y')

# one of the commands in "dt" is strftime
# strftime (string formatted time) --> convert timestamp object into string representation (following a specified format)

# y --> 25
# Y --> 2025
# Out:
# <ipython-input-15-09505b910db8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['FormattedDate'] = df['Date'].dt.strftime('%d/%m/%Y')

# %%
df['FormattedDate'].dtype # O --> Object --> string
# Out:
# dtype('O')

# %%
df
# Out:
#                   Name                 Course   CourseLevel       Date  \
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 Python       Master  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  Ai & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 Python       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  Ai & Machine Learning      Beginner 2023-09-20
#
#    FormattedDate
# 0     10/09/2023
# 1     11/09/2023
# 2     12/09/2023
# 3     13/09/2023
# 5     14/09/2023
# 6     15/09/2023
# 7     16/09/2023
# 9     17/09/2023
# 10    18/09/2023
# 11    19/09/2023
# 12    20/09/2023

# %%
# remove 'Date' column

df = df.drop('Date', axis=1)

# axis 0 --> row
# axis 1 --> column

# %%
df
# Out:
#                   Name                 Course   CourseLevel FormattedDate
# 0   Christy Cunningham                 Python      Beginner    10/09/2023
# 1       Douglas Tucker                 Python       Master     11/09/2023
# 2       Travis Walters                   Java  Intermediate    12/09/2023
# 3     Nathaniel Harris        Web Development      Advanced    13/09/2023
# 5         Tonya Carter  Ai & Machine Learning      Beginner    14/09/2023
# 6           Erik Smith     Mobile Development      Beginner    15/09/2023
# 7   Kristopher Johnson                 Python      Beginner    16/09/2023
# 9          Robert Buck                 Python       Master     17/09/2023
# 10     Joseph Mcdonald                   Java  Intermediate    18/09/2023
# 11       Jerome Abbott        Web Development      Advanced    19/09/2023
# 12       William Riley  Ai & Machine Learning      Beginner    20/09/2023

# %%
df['Date'] = df['FormattedDate']

# %%
df = df.drop('FormattedDate', axis=1)

# %%
df
# Out:
#                   Name                 Course   CourseLevel        Date
# 0   Christy Cunningham                 Python      Beginner  10/09/2023
# 1       Douglas Tucker                 Python       Master   11/09/2023
# 2       Travis Walters                   Java  Intermediate  12/09/2023
# 3     Nathaniel Harris        Web Development      Advanced  13/09/2023
# 5         Tonya Carter  Ai & Machine Learning      Beginner  14/09/2023
# 6           Erik Smith     Mobile Development      Beginner  15/09/2023
# 7   Kristopher Johnson                 Python      Beginner  16/09/2023
# 9          Robert Buck                 Python       Master   17/09/2023
# 10     Joseph Mcdonald                   Java  Intermediate  18/09/2023
# 11       Jerome Abbott        Web Development      Advanced  19/09/2023
# 12       William Riley  Ai & Machine Learning      Beginner  20/09/2023

# %%
# we are done with basic data analysis / data cleaning

# %% [markdown]
# ## 4. Registering Fonts into Project

# %%
# registering 2 fonts into this project

# pdfmetrics; used to register fonts so that we can use it with pdf files

# one of the methods is 'registerFont()'

# TTFont() will need 2 inputs
# 1st - what font are u registering?
# 2nd - where is the file of the font?

pdfmetrics.registerFont(TTFont('Lora-Bold', '/content/drive/MyDrive/certgen/fonts/Lora-Bold.ttf'))
pdfmetrics.registerFont(TTFont('Lora-Regular', '/content/drive/MyDrive/certgen/fonts/Lora-Regular.ttf'))

# %%
# after registering, we can use these fonts in the project later!

# %% [markdown]
# ## 5. Creating Certificate Logic Function

# %%
# in this function, the logic of generating a cert will be inside!
# this function will receive 4 inputs (name, course, courseLevel, date)

# REUSE THIS FUNCTION 11 times

def certificate_generator(name, course, courseLevel, date):

  pdf_file_name = '/content/drive/MyDrive/certgen/certificates/'+ name + '-' + course + '-' + courseLevel + '.pdf'
  # to create John Doe's cert --> JohnDoe-Python-Beginner.pdf

  # canvas = blank screen

  # Canvas() will need 2 inputs
  # 1st input - where are you storing it? and the file name
  # 2nd input - what size (A4)

  c = canvas.Canvas(pdf_file_name, pagesize=landscape(A4))

  # drawImage() needs 5 inputs
  # 1. image
  # 2. x axis (coordinate 0)
  # 3. y axis (coordinate 0)
  # 4. width --> A4[1]
  # 5. height --> A4[0]

  template = '/content/drive/MyDrive/certgen/certificate_template.jpg'

  c.drawImage(template, 0, 0, A4[1], A4[0])

  # coordinate for center
  center_x = c._pagesize[0] / 2 # width/2
  center_y = c._pagesize[1] / 2 # height/2

  #print("Full width: " + str(c._pagesize[0])) # width
  #print("Full height: " + str(c._pagesize[1])) # height

  # now that we got the centre of x & y...
  # Lets set the font and draw the text

  #------
  # .setFont() --> need 2 inputs

  # 1st input --> font type
  # 2nd input --> font size (in px)

  #-----
  # .drawCentredString() --> needs 3 inputs
  # 1st input --> x coordinate on the canvas to draw
  # 2nd input --> y coordinate on the canvas to draw
  # 3rd input --> what u are drawing on the canvas

  # 1. Name
  c.setFont('Lora-Bold', 30)
  c.drawCentredString(center_x, center_y - 40, name)

  # 2. Course & Course Level
  c.setFont('Lora-Bold', 28)
  c.drawCentredString(center_x, center_y - 105, course + "-" + courseLevel)

  # 3. Date
  c.setFont('Lora-Bold', 17)
  c.drawCentredString(center_x + 190, center_y - 160, date)

  # Cert ID
  cert_id = "CERT ID: " + str(pd.Timestamp.now().timestamp()).replace(".", "") # generate a unique ID based on current time
  c.setFont('Lora-Regular', 12)
  c.drawCentredString(center_x + 266, center_y - 230, cert_id)

  c.save()

# %%
certificate_generator("Jane Doe", "Python", "Beginner", "10/09/2023")
# Out:
# Full width: 841.8897637795277
# Full height: 595.2755905511812

# %%
# For Cert ID, it has to be unique, we can uniquely generate an ID based on current time (using pd.Timestamp)

print(pd.Timestamp.now()) # GMT +0 / UTC Time
print(pd.Timestamp.now().timestamp()) # Unix timestamp (number of seconds since January 1 1970)
print(str(pd.Timestamp.now().timestamp()).replace(".", ""))

# .replace() need 2 inputs
# 1st --> what u are going to replace
# 2nd --> what u are going to replace with
# Out:
# 2025-02-09 12:42:20.139205
# 1739104940.139413
# 1739104940139589

# %%
# later on we are going loop thru the df

# looping takes time - thats why we are using timestamp as our unique as the milliseconds are different

for x in range(10):
  print(pd.Timestamp.now())
# Out:
# 2025-02-09 12:57:09.871907
# 2025-02-09 12:57:09.880736
# 2025-02-09 12:57:09.880802
# 2025-02-09 12:57:09.880828
# 2025-02-09 12:57:09.880852
# 2025-02-09 12:57:09.880873
# 2025-02-09 12:57:09.880894
# 2025-02-09 12:57:09.880919
# 2025-02-09 12:57:09.880941
# 2025-02-09 12:57:09.880962

# %%
certificate_generator("Adam", "Python", "Beginner", "10/09/2024")
certificate_generator("Betty", "Python", "Advanced", "10/08/2024")
# Out:
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Full width: 841.8897637795277
# Full height: 595.2755905511812

# %%
df
# Out:
#                   Name                 Course   CourseLevel        Date
# 0   Christy Cunningham                 Python      Beginner  10/09/2023
# 1       Douglas Tucker                 Python       Master   11/09/2023
# 2       Travis Walters                   Java  Intermediate  12/09/2023
# 3     Nathaniel Harris        Web Development      Advanced  13/09/2023
# 5         Tonya Carter  Ai & Machine Learning      Beginner  14/09/2023
# 6           Erik Smith     Mobile Development      Beginner  15/09/2023
# 7   Kristopher Johnson                 Python      Beginner  16/09/2023
# 9          Robert Buck                 Python       Master   17/09/2023
# 10     Joseph Mcdonald                   Java  Intermediate  18/09/2023
# 11       Jerome Abbott        Web Development      Advanced  19/09/2023
# 12       William Riley  Ai & Machine Learning      Beginner  20/09/2023

# %%
# there are 11 students, the idea is USING THE FUNCTION 11 TIMES (with 4 diff inputs)

# use a for loop --> loop 11 times --> use function 11 times based on different 4 inputs

for x in ['Donald', 'The', 'Duck']:
  print(x)
# Out:
# Donald
# The
# Duck

# %%
# enumerate() keeps track of the index of each item
# it returns two items. 1st: index, 2nd: list item

for x in enumerate(['Donald', 'The', 'Duck']):
  print(x)
# Out:
# (0, 'Donald')
# (1, 'The')
# (2, 'Duck')

# %%
for x in df:
  print(x) # column names, not rows

  # this will loop thru columns
# Out:
# Name
# Course
# CourseLevel
# Date

# %%
# df.iterrows gives u loopable (array-like)
# df.iterrows gives you two items (index, item row)

for index, x in df.iterrows():
  print(x)
  print('-------')
# Out:
# Name           Christy Cunningham
# Course                     Python
# CourseLevel              Beginner
# Date                   10/09/2023
# Name: 0, dtype: object
# -------
# Name           Douglas Tucker
# Course                 Python
# CourseLevel           Master
# Date               11/09/2023
# Name: 1, dtype: object
# -------
# Name           Travis Walters
# Course                   Java
# CourseLevel      Intermediate
# Date               12/09/2023
# Name: 2, dtype: object
# -------
# Name           Nathaniel Harris
# Course          Web Development
# CourseLevel            Advanced
# Date                 13/09/2023
# Name: 3, dtype: object
# -------
# Name                    Tonya Carter
# Course         Ai & Machine Learning
# CourseLevel                 Beginner
# Date                      14/09/2023
# Name: 5, dtype: object
# -------
# Name                   Erik Smith
# Course         Mobile Development
# CourseLevel              Beginner
# Date                   15/09/2023
# Name: 6, dtype: object
# -------
# Name           Kristopher Johnson
# Course                     Python
# CourseLevel              Beginner
# Date                   16/09/2023
# Name: 7, dtype: object
# -------
# Name           Robert Buck
# Course              Python
# CourseLevel        Master
# Date            17/09/2023
# Name: 9, dtype: object
# -------
# Name           Joseph Mcdonald
# Course                    Java
# CourseLevel       Intermediate
# Date                18/09/2023
# Name: 10, dtype: object
# -------
# Name             Jerome Abbott
# Course         Web Development
# CourseLevel           Advanced
# Date                19/09/2023
# Name: 11, dtype: object
# -------
# Name                   William Riley
# Course         Ai & Machine Learning
# CourseLevel                 Beginner
# Date                      20/09/2023
# Name: 12, dtype: object
# -------

# %%
for index, x in df.iterrows():
  certificate_generator(x['Name'], x['Course'], x['CourseLevel'], x['Date'])
  print(x)
  print('-------')

print(str(len(df)) + " certificates generated successfully.")
# Out:
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name           Christy Cunningham
# Course                     Python
# CourseLevel              Beginner
# Date                   10/09/2023
# Name: 0, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name           Douglas Tucker
# Course                 Python
# CourseLevel           Master
# Date               11/09/2023
# Name: 1, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name           Travis Walters
# Course                   Java
# CourseLevel      Intermediate
# Date               12/09/2023
# Name: 2, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name           Nathaniel Harris
# Course          Web Development
# CourseLevel            Advanced
# Date                 13/09/2023
# Name: 3, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name                    Tonya Carter
# Course         Ai & Machine Learning
# CourseLevel                 Beginner
# Date                      14/09/2023
# Name: 5, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name                   Erik Smith
# Course         Mobile Development
# CourseLevel              Beginner
# Date                   15/09/2023
# Name: 6, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name           Kristopher Johnson
# Course                     Python
# CourseLevel              Beginner
# Date                   16/09/2023
# Name: 7, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name           Robert Buck
# Course              Python
# CourseLevel        Master
# Date            17/09/2023
# Name: 9, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name           Joseph Mcdonald
# Course                    Java
# CourseLevel       Intermediate
# Date                18/09/2023
# Name: 10, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name             Jerome Abbott
# Course         Web Development
# CourseLevel           Advanced
# Date                19/09/2023
# Name: 11, dtype: object
# -------
# Full width: 841.8897637795277
# Full height: 595.2755905511812
# Name                   William Riley
# Course         Ai & Machine Learning
# CourseLevel                 Beginner
# Date                      20/09/2023
# Name: 12, dtype: object
# -------
# 11 certificates generated successfully.
